# %% [markdown]
# ## Get and display raw data

# %% [markdown]
# ### import necessary

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### show raw data

# %%
data = pd.read_csv('../data/raw/total-fish-stocks.csv')
data.head()
# Out:
#    general_total_biomass  general_total_catch  general_exploitation_rate  \
# 0              1140000.0                  NaN                        NaN
# 1              1130000.0                  NaN                        NaN
# 2              1110000.0                  NaN                        NaN
# 3              1100000.0                  NaN                        NaN
# 4              1090000.0                  NaN                        NaN
#
#    biomass_relative_to_msy  harvest_relative_to_preferred_rate  \
# 0                     2.72                               0.112
# 1                     2.69                               0.157
# 2                     2.65                               0.131
# 3                     2.63                               0.118
# 4                     2.61                               0.196
#
#    biomass_relative_to_preferred_management_rate  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#    harvest_rate_relative_to_management_target  total_biomass  \
# 0                                       0.112      1140000.0
# 1                                       0.157      1130000.0
# 2                                       0.131      1110000.0
# 3                                       0.118      1100000.0
# 4                                       0.196      1090000.0
#
#    spawning_stock_biomass  total_number  ...  \
# 0                     NaN           NaN  ...
# 1                     NaN           NaN  ...
# 2                     NaN           NaN  ...
# 3                     NaN           NaN  ...
# 4                     NaN           NaN  ...
#
#    exploitation_rate_relative_to_management_target  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    catch_corresponding_to_total_allowable_advised  total_allowable_catch  \
# 0                                             NaN                    NaN
# 1                                             NaN                    NaN
# 2                                             NaN                    NaN
# 3                                             NaN                    NaN
# 4                                             NaN                    NaN
#
#    scientific_advice_for_catch_limit  survey_biomass  catch_per_unit_effort  \
# 0                                NaN             NaN                    NaN
# 1                                NaN             NaN                    NaN
# 2                                NaN             NaN                    NaN
# 3                                NaN             NaN                    NaN
# 4                                NaN             NaN                    NaN
#
#    fishing_effort                           Entity  Year  \
# 0             NaN  Albacore tuna Northern Atlantic  1930
# 1             NaN  Albacore tuna Northern Atlantic  1931
# 2             NaN  Albacore tuna Northern Atlantic  1932
# 3             NaN  Albacore tuna Northern Atlantic  1933
# 4             NaN  Albacore tuna Northern Atlantic  1934
#
#    biomass_relative_to-preferred_management_rate
# 0                                           2.72
# 1                                           2.69
# 2                                           2.65
# 3                                           2.63
# 4                                           2.61
#
# [5 rows x 37 columns]

# %%
data.tail()
# Out:
#      general_total_biomass  general_total_catch  general_exploitation_rate  \
# 431              2140000.0             522000.0                   0.243925
# 432              2110000.0             606000.0                   0.287204
# 433              2140000.0             554000.0                   0.258879
# 434              2320000.0             588000.0                   0.253448
# 435              2580000.0             576000.0                   0.223256
#
#      biomass_relative_to_msy  harvest_relative_to_preferred_rate  \
# 431                     1.37                               0.691
# 432                     1.24                               0.728
# 433                     1.21                               0.718
# 434                     1.35                               0.658
# 435                     1.44                               0.623
#
#      biomass_relative_to_preferred_management_rate  \
# 431                                            NaN
# 432                                            NaN
# 433                                            NaN
# 434                                            NaN
# 435                                            NaN
#
#      harvest_rate_relative_to_management_target  total_biomass  \
# 431                                       0.691      2140000.0
# 432                                       0.728      2110000.0
# 433                                       0.718      2140000.0
# 434                                       0.658      2320000.0
# 435                                       0.623      2580000.0
#
#      spawning_stock_biomass  total_number  ...  \
# 431               1150000.0           NaN  ...
# 432               1040000.0           NaN  ...
# 433               1010000.0           NaN  ...
# 434               1140000.0           NaN  ...
# 435               1210000.0           NaN  ...
#
#      exploitation_rate_relative_to_management_target  \
# 431                                              NaN
# 432                                              NaN
# 433                                              NaN
# 434                                              NaN
# 435                                              NaN
#
#      catch_corresponding_to_total_allowable_advised  total_allowable_catch  \
# 431                                             NaN                    NaN
# 432                                             NaN                    NaN
# 433                                             NaN                    NaN
# 434                                             NaN                    NaN
# 435                                             NaN                    NaN
#
#      scientific_advice_for_catch_limit  survey_biomass  catch_per_unit_effort  \
# 431                                NaN             NaN                    NaN
# 432                                NaN             NaN                    NaN
# 433                                NaN             NaN                    NaN
# 434                                NaN             NaN                    NaN
# 435                                NaN             NaN                    NaN
#
#      fishing_effort                                        Entity  Year  \
# 431             NaN  Yellowfin tuna Central Western Pacific Ocean  2011
# 432             NaN  Yellowfin tuna Central Western Pacific Ocean  2012
# 433             NaN  Yellowfin tuna Central Western Pacific Ocean  2013
# 434             NaN  Yellowfin tuna Central Western Pacific Ocean  2014
# 435             NaN  Yellowfin tuna Central Western Pacific Ocean  2015
#
#      biomass_relative_to-preferred_management_rate
# 431                                           1.37
# 432                                           1.24
# 433                                           1.21
# 434                                           1.35
# 435                                           1.44
#
# [5 rows x 37 columns]

# %% [markdown]
# ### check name of all column

# %%
data.columns
# Out:
# Index(['general_total_biomass', 'general_total_catch',
#        'general_exploitation_rate', 'biomass_relative_to_msy',
#        'harvest_relative_to_preferred_rate',
#        'biomass_relative_to_preferred_management_rate',
#        'harvest_rate_relative_to_management_target', 'total_biomass',
#        'spawning_stock_biomass', 'total_number', 'recruits', 'total_catch',
#        'total_landings', 'recreational_catch', 'fishing_mortality',
#        'exploitation_rate', 'total_biomass_relative_to_msy',
#        'spawning_stock_relative_to_msy', 'number_relative_to_msy',
#        'fishing_mortality_relative_to_msy',
#        'exploitation_rate_relative_to_msy', 'catch_relative_to_msy',
#        'catch_relative_to_mean_catch',
#        'total_biomass_relative_to_management_target',
#        'spawning_stock_relative_to_management_target',
#        'number_relative_to_management_target',
#        'fishing_mortality_relative_to_management_target',
#        'exploitation_rate_relative_to_management_target',
#        'catch_corresponding_to_total_allowable_advised',
#        'total_allowable_catch', 'scientific_advice_for_catch_limit',
#        'survey_biomass', 'catch_per_unit_effort', 'fishing_effort', 'Entity',
#        'Year', 'biomass_relative_to-preferred_management_rate'],
#       dtype='object')

# %% [markdown]
# ### plot key factor

# %%
# Plot using Seaborn
plt.figure(figsize=(10, 6))
sns.lineplot(data=data, x='Year', y='total_biomass', marker='o')
plt.title('Total Biomass Over Years', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Total Biomass', fontsize=12)
plt.grid(True)
file_path = '../results/figures/raw_total_biomass.png'
plt.savefig(file_path, dpi=300, bbox_inches='tight')
print(f'Saved figure in {file_path}')
plt.show()
# Out:
# Saved figure in ../results/figures/raw_total_biomass.png

# %%
# Plot using Seaborn
plt.figure(figsize=(10, 6))
sns.lineplot(data=data, x='Year', y='total_catch', marker='o')
plt.title('Total catch Over Years', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Total catch', fontsize=12)
plt.grid(True)
file_path = '../results/figures/raw_total_catch.png'
plt.savefig(file_path, dpi=300, bbox_inches='tight')
print(f'Saved figure in {file_path}')
plt.show()
# Out:
# Saved figure in ../results/figures/raw_total_catch.png

# %% [markdown]
# ### basic cleaning

# %%
# Step 1: Remove duplicate or potentially misspelled columns
data = data.rename(columns={
    'biomass_relative_to-preferred_management_rate': 'biomass_relative_to_preferred_management_rate'
})

# Step 2: Remove "general" columns if they are aggregations of detailed metrics
data = data.drop(columns=['general_total_biomass', 'general_total_catch', 'general_exploitation_rate'], errors='ignore')

# Step 3: Select one baseline for "relative to" metrics
columns_to_keep = [
    'biomass_relative_to_msy', 'total_biomass_relative_to_msy', 'spawning_stock_relative_to_msy',
    'catch_relative_to_msy', 'fishing_mortality_relative_to_msy'
]
relative_columns = [col for col in data.columns if '_relative_to_' in col]
columns_to_drop = [col for col in relative_columns if col not in columns_to_keep]
data = data.drop(columns=columns_to_drop, errors='ignore')

# Step 4: Ensure columns are distinct and meaningful
data = data.drop(columns=['total_landings'], errors='ignore')  # Assuming `total_catch` is enough
data = data.drop(columns=['catch_relative_to_mean_catch'], errors='ignore')  # Likely less relevant
data = data.drop(columns=['recruits'], errors='ignore')  # Highly specific, might not be necessary

# Step 5: Keep only meaningful effort and biomass metrics
data = data.drop(columns=['survey_biomass'], errors='ignore')  # If less relevant than `total_biomass`
data = data.drop(columns=['catch_per_unit_effort'], errors='ignore')  # If `fishing_effort` suffices

# Print final columns for review
latest_column = data.columns.tolist()
print(f'Num of column: {len(latest_column)}')
print("Modified Columns:")
print(latest_column)
# Out:
# Num of column: 18
# Modified Columns:
# ['biomass_relative_to_msy', 'total_biomass', 'spawning_stock_biomass', 'total_number', 'total_catch', 'recreational_catch', 'fishing_mortality', 'exploitation_rate', 'total_biomass_relative_to_msy', 'spawning_stock_relative_to_msy', 'fishing_mortality_relative_to_msy', 'catch_relative_to_msy', 'catch_corresponding_to_total_allowable_advised', 'total_allowable_catch', 'scientific_advice_for_catch_limit', 'fishing_effort', 'Entity', 'Year']

# %%
# Example: Summing all numeric columns for each year
data_grouped = data.groupby('Year').sum(numeric_only=True).reset_index()

# Sort the grouped DataFrame by 'Year' in ascending order
data_grouped = data_grouped.sort_values(by='Year', ascending=True)

file_path = '../data/raw/clean1.csv'

data_grouped.to_csv('../data/processed/clean1.csv',index=False)
print(f'Saved file in {file_path}')
# Out:
# Saved file in ../data/raw/clean1.csv
